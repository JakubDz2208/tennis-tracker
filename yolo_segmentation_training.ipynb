# %%
from ultralytics import YOLO
import numpy as np
import cv2
from mss import mss
from PIL import Image, ImageDraw
from collections import defaultdict
import torch

model = YOLO("yolov8m-seg.pt")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

model.to(device)

# %%
video_path = "tenis.mp4"

cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    success, frame = cap.read()

    if success:
        results = model.track(frame, persist=True)

        annotated_frame = results[0].plot()

        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q") or cv2.waitKey(1) & 0xFF == ord("Q"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 persons, 1 tv, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="5mqoh9mjqapU2jwm7y8A")

project = rf.workspace("tennistracker-dogbm").project("tennis-court-detection")

version = project.version(9)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.160, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to tennis-court-detection-9 in yolov8:: 100%|██████████| 254/254 [00:00<00:00, 1417.64it/s]

# %%
print(dataset)

# %%
results = model.train(data='C:/Users/Kuba/Desktop/-/object-detection/tennis-court-detection-9/data.yaml', epochs=5)
# Out:
# New https://pypi.org/project/ultralytics/8.2.5 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.160  Python-3.11.3 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# ...
